# %%
import pandas as pd
import numpy as np
import os
from IPython.display import display, HTML
from sklearn.externals import joblib
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import pickle
import os
from joblib import dump, load
from google.colab import drive
from sklearn.model_selection import train_test_split
from tqdm import tqdm
pd.set_option('display.width', 500)
pd.options.display.max_rows
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

def final_model(X):

  '''
    Function to Train a model, Save trained model and predict the values on the model.
    All the Data preprocessing, cleaning, prediction is at one place.
    Expected input is the raw data.
    Expected output is the list of predicted values.  
  '''

  clean_data(X)
  preprocess_data(X)
  return do_predict(X)


def clean_data(X):

  '''
  Function to clean the raw data.
  Any missing values will be filled, less/high importance values are removed or grouped as others.
  This function is subjective to modify depend onthe observations on EDA.

  X : DataFrame containing raw or cleaned data. 
  '''

  print('## Data Cleaning - filling missing values for categorical data')
  for cat in cat_feat :
    if cat in X:
      X[cat].fillna(MISSING, inplace=True)
      X[cat] = X[cat].astype(str)

  # Numerical features : fill missing values with median.
  print('## Data Cleaning - filling missing values for numerical data')
  for cat in [col for col in X.columns if col not in cat_feat]:
    X[cat].fillna(X[cat].median(), inplace=True)

  # All the versions of the same OS categories are grouped together.
  # Here we are not taking advantage of the versions specified.
  X.loc[X['id_30'].str.contains('Windows', na=False), 'id_30'] = 'Windows'
  X.loc[X['id_30'].str.contains('iOS', na=False), 'id_30'] = 'iOS'
  X.loc[X['id_30'].str.contains('Mac OS', na=False), 'id_30'] = 'Mac'
  X.loc[X['id_30'].str.contains('Android', na=False), 'id_30'] = 'Android'

  #All the versions of the same Web browser categories are grouped together.
  #Here we are not taking advantage of the versions specified.
  X.loc[X['id_31'].str.contains('chrome', na=False), 'id_31'] = 'Chrome'
  X.loc[X['id_31'].str.contains('firefox', na=False), 'id_31'] = 'Firefox'
  X.loc[X['id_31'].str.contains('safari', na=False), 'id_31'] = 'Safari'
  X.loc[X['id_31'].str.contains('edge', na=False), 'id_31'] = 'Edge'
  X.loc[X['id_31'].str.contains('ie', na=False), 'id_31'] = 'IE'
  X.loc[X['id_31'].str.contains('samsung', na=False), 'id_31'] = 'Samsung'
  X.loc[X['id_31'].str.contains('opera', na=False), 'id_31'] = 'Opera'


def preprocess_data(X):

  '''
  Function to convert feature specific values to machine understandable language.
  Categorical features are converted to labels by encoding through LabelEncoder.

  X : DataFrame.
  '''
  print('## Data Preprocessing - loading labelencoder')
  for col in [col for col in cat_feat if col in X.columns]:
    file = open(data_path+col+enc_file, 'rb')
    label_encoder = pickle.load(file)
    file.close()
    X[col] = label_encoder.transform(list(X[col].values))
    del label_encoder

  print('## Data Preprocessing - loading minmaxscalar')
  file = open(data_path+scal_file, 'rb')
  scaler = pickle.load(file)
  file.close()
  numerical_columns = [col for col in X.columns if col not in cat_feat]
  X[numerical_columns] = scaler.transform(X[numerical_columns])

  return


def do_predict(X):
  '''
  Function to predict and return the values as list.
  if there is no model trained and saved to predict, train and save the model.

  X : Data Frame containing values in model understandable data to predict.
  '''

  from sklearn.externals import joblib
  import lightgbm as lgb
  # load model
  print('## Predicting - Load model')
  clf = joblib.load(data_path+model_file)
  print('## Predicting - predicting values')
  return clf.predict(X)


def train_model(X, Y) :

  '''
  Function to train the model. 
  X, Y are expected to be raw data for training. 
  cleaning the data, preprocessing, training and saving the final model.
  '''
  
  clean_data(X)
  # if there is no encoder file, create file.
  
  if (not os.path.exists(data_path+enc_file)):
    print('## Preprocessing - labelencoding categorical features')
    for col in [c for c in cat_feat if c in X.columns] : 
      label_encoder = LabelEncoder()
      val = list(X[col].values)
      val.append(MISSING)
      val.append(Others)
      print('## In Training the model : categorical column type : ', type(val[0]))
      print(list(set(val)))
      label_encoder.fit(list(set(val)))
      X[col] = label_encoder.transform(list(X[col].values))
      output = open(data_path+col+enc_file, 'wb')
      pickle.dump(label_encoder, output)
      output.close()

  
  # if there is no scaling file, create file.
  if (not os.path.exists(data_path+scal_file)):
    print('## Preprocessing - Scaling numerical features')
    scaler = MinMaxScaler()
    numerical_columns = [col for col in X.columns if col not in cat_feat]
    X[numerical_columns] = scaler.fit_transform(X[numerical_columns])
    
    output = open(data_path+scal_file, 'wb')
    pickle.dump(scaler, output)
    output.close()
  
  if (not os.path.exists(data_path+model_file)):
    print('## Training - training the model')
    # train model if model is not saved yet.
    d_train = lgb.Dataset(X, label=Y)
    params = {}
    params['boosting_type'] = 'gbdt'
    params['objective'] = 'binary'
    params['metric'] = 'auc'
    params['sub_feature'] = 0.5
    params['min_data'] = 50
    params['max_depth'] = 10
    clf = lgb.train(params, d_train, 100)
    # save model
    print('Saving the model')
    joblib.dump(clf, data_path+model_file)


def metric(y_pred, y_actual):
  '''
    Function calculate the roc auc score and return the same
    Input : predicted values and actual values 
    output : roc auc score

  '''
  from sklearn.metrics import roc_auc_score
  return roc_auc_score(y_actual, y_pred)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# ## Load Data From Google Drive

# %%
drive.mount('/content/drive')
data_path_ = 'drive/My Drive/Case study/Fraud-Detection/data/'
train_df = pd.read_csv(f'{data_path_}train_df.csv', dtype={'card3': float,'card5': float})
test_df = pd.read_csv(f'{data_path_}test_df.csv', dtype={'card3': float,'card5': float})

# make datatypes 

# Constants
cat_feat = ['ProductCD', 'card1', 'card2', 'card3','card4', 'card5', 'card6', 'addr1', 'addr2', 'P_emaildomain',
              'R_emaildomain', 'M1', 'M2', 'M3','M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'id_12', 'id_13', 'id_14', 'id_15', 
              'id_16', 'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 
              'id_28', 'id_29', 'id_30', 'id_31', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 
              'DeviceType', 'DeviceInfo',]
# path to the case study folder
data_path= 'drive/My Drive/Case study/Fraud-Detection/'
# Trained Model save file name 
model_file = 'save_model.pkl'
# LabelEncoder save base file name after fitting on trained data.
enc_file = 'encoder_file.pkl'
# MinmaxScalar save base file name after fitting on trained data.
scal_file = 'scaler_file.pkl'
# Constant used to label nan values in categorical features.
MISSING = 'missing'
Others = "Others"

# Dividing train data into train and cv with 80:10 ratio
y = train_df['isFraud']
train_df.drop(['isFraud', 'TransactionID', 'TransactionDT'], axis=1, inplace=True)
test_df.drop(columns=['TransactionID', 'TransactionDT'], inplace=True)
train_df, cv_df, y_train, y_cv = train_test_split(train_df, y, test_size=0.10, random_state=42, stratify=y)

# We found unknown categories apart from train data.
# We need to find and make those categories as a missing category 
# because after training the model doesn't know the category.
def makeMissingCatIfNotPresent(train_val, val):
  if val in train_val:
    return str(val)
  else :
      return MISSING
# check if category values are there in train data else make it as missing category.
for col in tqdm(cat_feat) :
  uniques = train_df[col].unique()
  train_df[col] = train_df[col].apply(lambda x : makeMissingCatIfNotPresent(uniques, x))
  test_df[col] = test_df[col].apply(lambda x : makeMissingCatIfNotPresent(uniques, x))
  cv_df[col] = cv_df[col].apply(lambda x : makeMissingCatIfNotPresent(uniques, x))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 100%|██████████| 49/49 [05:43<00:00, 20.12s/it]

# %%
# Train model
if not os.path.exists(data_path+model_file):
  train_model(train_df.copy(deep=True), y_train)

# Metrics using final model function.

print('\n' + '*'*25 + 'Predicting for Train data' + '*'*25)
train_metric =  metric(final_model(train_df.copy(deep=True)), y_train)

print('\n' + '*'*25 + 'Predicting for CV data' + '*'*25)
cv_metric =  metric(final_model(cv_df.copy(deep=True)), y_cv)

print('\n')
print('Train metric : ', train_metric)
print('CV metric : ',cv_metric)
# Out:
# ## Data Cleaning - filling missing values for categorical data
# ## Data Cleaning - filling missing values for numerical data
# ## Preprocessing - labelencoding categorical features
# ## In Training the model : categorical column type :  <class 'str'>
# ['missing', 'H', 'Others', 'C', 'W', 'S', 'R']
# ## In Training the model : categorical column type :  <class 'str'>
# ['18005', '17066', '11667', '3984', '10271', '6505', '6964', '3132', '15229', '2459', '1659', '2906', '6306', '2295', '10513', '8751', '12984', '9856', '16228', '15423', '1090', '13497', '15439', '9505', '16448', '8926', '10511', '16436', '11816', '11653', '9066', '10474', '10022', '15097', '9527', '1608', '1790', '1488', '11664', '13729', '4556', '13765', '14691', '7185', '13509', '9613', '1337', '16869', '5347', '4619', '16205', '2194', '2268', '16009', '8963', '5128', '6805', '16879', '14973', '3640', '12648', '7576', '14310', '4023', '11405', '6297', '3808', '16025', '11827', '2472', '9227', '7077', '11030', '17439', '13302', '6146', '2870', '7002', '14392', '16278', '12978', '10926', '8960', '5978', '12602', '7149', '10152', '14916', '9079', '7330', '12035', '2802', '10821', '8167', '2435', '7640', '9120', '1738', '7784', '1849', '14773', '10470', '5284', '16549', '4825', '6897', '2820', '11974', '13113', '7607', '12622', '11981', '1665', '9183', '2409', '6219', '4190', '7733', '13120', '3788', '17787', '4694', '2484', '7027', '10807', '9878', '1011', '4069', '17511', '11732', '3388', '6995', '2695', '15080', '17166', '8790', '2687', '2890', '7536', '15522', '6924', '3386', '14968', '11811', '16135', '15617', '6233', '14456', '12468', '11880', '3086', '3260', '11048', '1200', '9361', '2232', '14260', '2671', '14433', '8857', '5170', '3051', '3421', '10633', '15330', '8637', '6339', '9214', '14352', '1944', '8017', '5374', '10844', '2845', '8427', '16640', '9861', '7186', '14321', '14864', '14835', '9940', '15989', '8027', '9147', '13608', '11574', '4800', '15054', '15660', '15553', '10944', '4957', '3217', '1351', '5859', '3515', '12585', '15525', '11772', '4658', '2911', '8050', '6882', '10526', '11718', '13993', '6292', '5161', '1051', '16234', '10538', '13630', '9908', '7153', '1557', '17090', '10876', '9256', '2497', '8397', '3977', '17674', '16498', '4231', '17815', '3373', '7434', '15639', '12022', '2778', '6829', '10249', '13674', '18129', '6459', '9711', '3582', '15391', '8028', '15121', '16151', '4937', '8142', '16457', '11630', '4868', '2316', '9368', '3800', '17007', '1368', '5871', '10310', '17644', '11856', '14957', '7547', '8114', '9115', '11002', '11891', '17512', '14701', '15511', '4696', '7162', '4340', '13296', '17626', '7754', '15267', '16053', '13813', '7896', '7325', '3684', '14026', '17416', '1214', '10575', '4220', '14002', '3790', '14057', '11700', '15771', '18066', '16849', '17638', '17940', '14515', '17997', '7278', '14080', '1189', '14020', '6984', '9532', '7374', '3354', '17414', '11672', '13437', '9725', '6858', '6546', '10583', '16105', '8206', '3027', '8233', '16054', '3361', '15068', '7222', '6279', '1868', '14132', '5094', '18373', '3280', '11239', '1221', '16742', '2569', '9065', '2161', '8216', '16223', '3664', '15344', '2760', '3738', '17619', '9886', '11658', '14271', '3202', '10715', '2469', '8571', '8143', '9625', '14032', '7241', '9935', '14391', '1248', '4755', '9560', '6396', '12738', '8727', '5394', '16829', '4437', '8087', '10216', '5623', '3854', '5328', '18228', '13890', '16555', '2097', '5959', '15009', '16681', '3792', '18374', '1117', '6513', '10892', '5760', '2541', '16467', '2252', '8703', '7564', '4013', '10630', '14560', '4750', '12803', '16371', '14842', '14507', '15145', '6753', '17621', '3205', '3601', '16077', '9452', '4076', '10373', '12642', '3124', '13905', '9316', '14444', '9486', '17805', '15752', '7203', '16580', '13810', '5879', '12750', '1556', '5990', '8999', '13285', '16471', '14123', '15194', '1696', '2147', '7637', '12070', '7211', '4034', '17268', '4819', '2709', '5680', '14430', '16819', '16402', '13227', '12937', '18305', '2496', '7371', '5080', '4926', '6318', '14434', '8794', '7423', '18183', '1392', '3852', '16732', '10983', '16259', '12516', '8626', '3748', '7379', '17810', '9474', '12667', '8757', '11476', '18249', '3621', '16289', '12353', '4425', '13708', '6405', '17046', '15738', '3293', '5539', '8334', '12199', '9948', '7522', '9654', '9439', ...
# ## In Training the model : categorical column type :  <class 'str'>
# ['597.0', '205.0', '567.0', '366.0', '383.0', '511.0', '314.0', '450.0', '308.0', '517.0', '470.0', '392.0', '410.0', '430.0', '245.0', '198.0', '588.0', '555.0', '274.0', '239.0', '208.0', '304.0', '190.0', '399.0', '559.0', '530.0', '332.0', '262.0', '390.0', '508.0', '206.0', '521.0', '434.0', '203.0', '439.0', '318.0', '166.0', '148.0', '487.0', '433.0', '526.0', '367.0', '540.0', '249.0', '356.0', '479.0', '463.0', '537.0', '156.0', '474.0', '582.0', '482.0', '187.0', '105.0', '557.0', '223.0', '419.0', '538.0', '344.0', '320.0', '101.0', '250.0', '226.0', '299.0', '485.0', '182.0', '275.0', '415.0', '201.0', '464.0', '336.0', '556.0', '327.0', '284.0', '542.0', '297.0', '394.0', '175.0', '345.0', '534.0', '387.0', '578.0', '364.0', '494.0', '138.0', '315.0', '255.0', '157.0', '246.0', '468.0', '527.0', '171.0', '593.0', '234.0', '473.0', '183.0', '539.0', '424.0', '313.0', '268.0', '254.0', '173.0', '372.0', '285.0', '328.0', '509.0', '290.0', '224.0', '423.0', '546.0', '489.0', '296.0', '289.0', '325.0', '375.0', '515.0', '503.0', '492.0', '189.0', '305.0', '586.0', '121.0', '453.0', '301.0', '425.0', '560.0', '359.0', '130.0', '456.0', '145.0', '563.0', '574.0', '580.0', '273.0', '111.0', '215.0', '477.0', '532.0', '132.0', '437.0', '500.0', '122.0', '329.0', '570.0', '242.0', '119.0', '599.0', '160.0', '596.0', '126.0', '259.0', '354.0', '585.0', '140.0', '118.0', '420.0', '146.0', '598.0', '451.0', '524.0', '143.0', '104.0', '241.0', '191.0', '222.0', '401.0', '397.0', '436.0', '478.0', '300.0', '321.0', '452.0', '353.0', '469.0', '334.0', '181.0', '103.0', '446.0', '322.0', '195.0', '350.0', '566.0', '341.0', '307.0', '432.0', '536.0', '154.0', '233.0', '357.0', '523.0', '202.0', '369.0', '400.0', '150.0', '169.0', '361.0', '309.0', '486.0', '444.0', '136.0', '398.0', '113.0', '266.0', '564.0', '178.0', '362.0', '227.0', '196.0', '282.0', '514.0', '303.0', '491.0', '576.0', '212.0', '112.0', '177.0', '291.0', '152.0', '312.0', '172.0', '391.0', '411.0', '134.0', '480.0', '174.0', '316.0', '373.0', '565.0', '370.0', '335.0', '176.0', '569.0', '219.0', '505.0', '407.0', '151.0', 'missing', '471.0', '277.0', '216.0', '261.0', '371.0', '413.0', '158.0', '416.0', '409.0', '558.0', '545.0', '129.0', '522.0', '281.0', '149.0', '583.0', '462.0', '389.0', '283.0', '552.0', '490.0', '218.0', '550.0', '294.0', '120.0', '293.0', '447.0', '167.0', '426.0', '330.0', '243.0', '310.0', '455.0', '248.0', '441.0', '498.0', '551.0', '147.0', '457.0', '292.0', '340.0', '139.0', '355.0', '427.0', '365.0', '331.0', '326.0', '378.0', '337.0', '382.0', '506.0', '381.0', '403.0', '377.0', '108.0', '116.0', '519.0', '170.0', '135.0', '435.0', '428.0', '179.0', '319.0', '237.0', '333.0', '493.0', '258.0', '445.0', '339.0', 'Others', '211.0', '109.0', '422.0', '589.0', '374.0', '440.0', '164.0', '476.0', '496.0', '264.0', '200.0', '475.0', '306.0', '229.0', '127.0', '465.0', '358.0', '396.0', '271.0', '466.0', '217.0', '352.0', '448.0', '581.0', '507.0', '225.0', '380.0', '287.0', '472.0', '571.0', '553.0', '256.0', '461.0', '525.0', '194.0', '298.0', '114.0', '214.0', '220.0', '276.0', '412.0', '467.0', '251.0', '544.0', '125.0', '280.0', '100.0', '161.0', '347.0', '230.0', '185.0', '541.0', '349.0', '270.0', '163.0', '351.0', '386.0', '385.0', '531.0', '376.0', '199.0', '155.0', '454.0', '384.0', '228.0', '348.0', '159.0', '449.0', '168.0', '406.0', '504.0', '162.0', '244.0', '278.0', '360.0', '128.0', '418.0', '431.0', '343.0', '192.0', '311.0', '528.0', '488.0', '295.0', '272.0', '595.0', '572.0', '405.0', '579.0', '458.0', '502.0', '577.0', '443.0', '575.0', '535.0', '402.0', '442.0', '238.0', '549.0', '481.0', '288.0', '279.0', '252.0', '484.0', '520.0', '263.0', '590.0', '210.0', '302.0', '142.0', '408.0', '499.0', '153.0', '497.0', '197.0', '562.0', '495.0', '573.0', '568.0', '267.0', '265.0', '115.0', '510.0', '213.0', '543.0', '561.0', '421.0', '144.0', '232.0', '317.0', '204.0', '529.0', '483.0', '393.0', '269.0', '231.0', '518.0',  ...
# ## In Training the model : categorical column type :  <class 'str'>
# ['120.0', '111.0', '215.0', '205.0', '128.0', '167.0', '122.0', '119.0', '160.0', '126.0', '118.0', '146.0', '147.0', '143.0', '198.0', '139.0', '208.0', '190.0', '191.0', '222.0', '206.0', '203.0', '108.0', '116.0', '135.0', '170.0', '166.0', '148.0', '179.0', '181.0', '195.0', '156.0', '211.0', 'Others', '109.0', '210.0', '142.0', '164.0', '105.0', '200.0', '153.0', '197.0', '229.0', '127.0', '223.0', '202.0', '150.0', '169.0', '217.0', '101.0', '213.0', '226.0', '136.0', '144.0', '182.0', '225.0', '204.0', '201.0', '231.0', '194.0', '227.0', '114.0', '175.0', '214.0', '220.0', '212.0', '177.0', '152.0', '172.0', '186.0', '134.0', '138.0', '180.0', '157.0', '102.0', '174.0', '125.0', '171.0', '207.0', '209.0', '100.0', '124.0', '183.0', '161.0', '185.0', '173.0', '123.0', '163.0', '176.0', '219.0', '131.0', '188.0', '133.0', '151.0', 'missing', '224.0', '141.0', '184.0', '199.0', '137.0', '189.0', '155.0', '107.0', '228.0', '117.0', '121.0', '193.0', '159.0', '129.0', '106.0', '149.0', '168.0', '130.0', '221.0', '162.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['missing', 'mastercard', 'visa', 'american express', 'Others', 'discover']
# ## In Training the model : categorical column type :  <class 'str'>
# ['120.0', '111.0', '215.0', '205.0', '132.0', '128.0', '167.0', '122.0', '119.0', '160.0', '126.0', '140.0', '118.0', '146.0', '147.0', '143.0', '198.0', '104.0', '139.0', '190.0', '191.0', '222.0', '206.0', '203.0', '116.0', '135.0', '166.0', '148.0', '237.0', '195.0', '156.0', '211.0', 'Others', '109.0', '233.0', '210.0', '142.0', '187.0', '164.0', '105.0', '200.0', '197.0', '229.0', '127.0', '223.0', '202.0', '150.0', '169.0', '115.0', '217.0', '101.0', '213.0', '226.0', '136.0', '144.0', '182.0', '225.0', '232.0', '204.0', '113.0', '201.0', '231.0', '178.0', '194.0', '196.0', '114.0', '214.0', '212.0', '112.0', '177.0', '152.0', '172.0', '134.0', '138.0', '180.0', '157.0', '102.0', '235.0', '207.0', '171.0', '125.0', '209.0', '234.0', '100.0', '183.0', '230.0', '185.0', '173.0', '123.0', '163.0', '165.0', '219.0', '131.0', '188.0', '133.0', '151.0', 'missing', '224.0', '141.0', '184.0', '216.0', '199.0', '137.0', '189.0', '107.0', '228.0', '158.0', '117.0', '236.0', '121.0', '159.0', '129.0', '149.0', '106.0', '130.0', '168.0', '145.0', '162.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['credit', 'missing', 'charge card', 'Others', 'debit', 'debit or credit']
# ## In Training the model : categorical column type :  <class 'str'>
# ['294.0', '120.0', '111.0', '215.0', '205.0', '477.0', '132.0', '244.0', '278.0', '360.0', '128.0', '418.0', '167.0', '426.0', '431.0', '122.0', '366.0', '329.0', '500.0', '242.0', '511.0', '343.0', '119.0', '160.0', '314.0', '450.0', '330.0', '308.0', '517.0', '126.0', '259.0', '528.0', '243.0', '310.0', '470.0', '420.0', '410.0', '381.0', '441.0', '498.0', '146.0', '430.0', '488.0', '451.0', '457.0', '292.0', '143.0', '104.0', '198.0', '139.0', '340.0', '427.0', '295.0', '208.0', '239.0', '274.0', '365.0', '272.0', '304.0', '331.0', '326.0', '190.0', '399.0', '241.0', '191.0', '337.0', '332.0', '382.0', '262.0', '401.0', '436.0', '397.0', '478.0', '390.0', '508.0', '206.0', '521.0', '458.0', '502.0', '203.0', '439.0', '300.0', '443.0', '321.0', '452.0', '353.0', '318.0', '519.0', '170.0', '435.0', '166.0', '148.0', '535.0', '433.0', '428.0', '469.0', '402.0', '526.0', '238.0', '237.0', '333.0', '181.0', '540.0', '481.0', '258.0', '356.0', '479.0', '513.0', '493.0', '445.0', '463.0', '339.0', '446.0', '279.0', '252.0', '156.0', '322.0', '211.0', '474.0', '195.0', 'Others', '520.0', '307.0', '341.0', '432.0', '536.0', '154.0', '233.0', '482.0', '210.0', '142.0', '187.0', '164.0', '476.0', '374.0', '496.0', '408.0', '105.0', '302.0', '264.0', '499.0', '523.0', '306.0', '434.0', '127.0', '223.0', '202.0', '465.0', '369.0', '400.0', '358.0', '361.0', '396.0', '486.0', '265.0', '466.0', '217.0', '352.0', '101.0', '444.0', '448.0', '213.0', '507.0', '226.0', '250.0', '299.0', '485.0', '144.0', '182.0', '225.0', '275.0', '377.0', '204.0', '472.0', '483.0', '529.0', '393.0', '269.0', '201.0', '464.0', '231.0', '518.0', '178.0', '194.0', '327.0', '284.0', '196.0', '298.0', '323.0', '282.0', '297.0', '514.0', '303.0', '110.0', '214.0', '260.0', '220.0', '491.0', '345.0', '387.0', '253.0', '276.0', '177.0', '112.0', '152.0', '312.0', '172.0', '467.0', '391.0', '494.0', '134.0', '411.0', '315.0', '368.0', '251.0', '180.0', '157.0', '255.0', '379.0', '102.0', '235.0', '527.0', '125.0', '171.0', '316.0', '234.0', '512.0', '174.0', '468.0', '100.0', '373.0', '124.0', '183.0', '161.0', '347.0', '313.0', '254.0', '268.0', '185.0', '349.0', '338.0', '257.0', '270.0', '123.0', '459.0', '163.0', '372.0', '335.0', '386.0', '351.0', '403.0', '219.0', '131.0', '286.0', '505.0', '328.0', '509.0', '385.0', '290.0', '151.0', '133.0', 'missing', '224.0', '531.0', '471.0', '324.0', '141.0', '489.0', '277.0', '296.0', '184.0', '216.0', '395.0', '325.0', '375.0', '376.0', '515.0', '492.0', '261.0', '199.0', '189.0', '155.0', '305.0', '137.0', '371.0', '417.0', '454.0', '384.0', '348.0', '158.0', '416.0', '409.0', '236.0', '193.0', '117.0', '501.0', '453.0', '301.0', '159.0', '425.0', '522.0', '429.0', '129.0', '106.0', '359.0', '462.0', '346.0', '389.0', '283.0', '130.0', '168.0', '145.0', '456.0', '404.0', '406.0', '504.0', '221.0', '218.0', '162.0', '247.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['44.0', '88.0', '15.0', '72.0', '39.0', '101.0', '25.0', '68.0', '78.0', '47.0', '23.0', '18.0', '28.0', '60.0', '46.0', '92.0', '50.0', '86.0', '17.0', '22.0', '35.0', 'missing', '59.0', '69.0', '14.0', '77.0', '98.0', '65.0', '49.0', 'Others', '21.0', '51.0', '38.0', '31.0', '71.0', '30.0', '84.0', '16.0', '96.0', '32.0', '54.0', '29.0', '79.0', '89.0', '52.0', '74.0', '48.0', '26.0', '19.0', '61.0', '62.0', '20.0', '73.0', '57.0', '13.0', '27.0', '55.0', '102.0', '24.0', '82.0', '40.0', '97.0', '94.0', '36.0', '66.0', '100.0', '10.0', '76.0', '87.0', '70.0', '34.0', '93.0', '43.0', '63.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['charter.net', 'aim.com', 'cox.net', 'protonmail.com', 'hotmail.fr', 'anonymous.com', 'windstream.net', 'rocketmail.com', 'aol.com', 'live.fr', 'sc.rr.com', 'gmail', 'outlook.es', 'gmx.de', 'mail.com', 'me.com', 'netzero.com', 'yahoo.co.uk', 'hotmail.co.uk', 'live.com.mx', 'comcast.net', 'suddenlink.net', 'missing', 'outlook.com', 'optonline.net', 'Others', 'cableone.net', 'yahoo.de', 'sbcglobal.net', 'frontier.com', 'netzero.net', 'bellsouth.net', 'hotmail.es', 'juno.com', 'centurylink.net', 'prodigy.net.mx', 'twc.com', 'embarqmail.com', 'ptd.net', 'mac.com', 'yahoo.fr', 'yahoo.es', 'hotmail.de', 'gmail.com', 'roadrunner.com', 'web.de', 'msn.com', 'ymail.com', 'yahoo.com.mx', 'live.com', 'yahoo.co.jp', 'yahoo.com', 'earthlink.net', 'frontiernet.net', 'cfl.rr.com', 'verizon.net', 'icloud.com', 'att.net', 'q.com', 'servicios-ta.com', 'hotmail.com']
# ## In Training the model : categorical column type :  <class 'str'>
# ['cox.net', 'charter.net', 'aim.com', 'protonmail.com', 'hotmail.fr', 'anonymous.com', 'rocketmail.com', 'windstream.net', 'aol.com', 'scranton.edu', 'live.fr', 'outlook.es', 'gmx.de', 'gmail', 'mail.com', 'me.com', 'yahoo.co.uk', 'netzero.com', 'hotmail.co.uk', 'live.com.mx', 'comcast.net', 'suddenlink.net', 'missing', 'outlook.com', 'sc.rr.com', 'optonline.net', 'Others', 'cableone.net', 'yahoo.de', 'sbcglobal.net', 'frontier.com', 'netzero.net', 'bellsouth.net', 'hotmail.es', 'juno.com', 'centurylink.net', 'prodigy.net.mx', 'ptd.net', 'embarqmail.com', 'twc.com', 'mac.com', 'yahoo.fr', 'hotmail.de', 'gmail.com', 'roadrunner.com', 'web.de', 'msn.com', 'yahoo.co.jp', 'yahoo.com.mx', 'live.com', 'ymail.com', 'yahoo.com', 'yahoo.es', 'earthlink.net', 'cfl.rr.com', 'verizon.net', 'icloud.com', 'att.net', 'frontiernet.net', 'q.com', 'servicios-ta.com', 'hotmail.com']
# ## In Training the model : categorical column type :  <class 'str'>
# ['F', 'Others', 'missing', 'T']
# ## In Training the model : categorical column type :  <class 'str'>
# ['F', 'Others', 'missing', 'T']
# ## In Training the model : categorical column type :  <class 'str'>
# ['F', 'Others', 'missing', 'T']
# ## In Training the model : categorical column type :  <class 'str'>
# ['missing', 'Others', 'M1', 'M0', 'M2']
# ## In Training the model : categorical column type :  <class 'str'>
# ['F', 'Others', 'missing', 'T']
# ## In Training the model : categorical column type :  <class 'str'>
# ['F', 'Others', 'missing', 'T']
# ## In Training the model : categorical column type :  <class 'str'>
# ['F', 'Others', 'missing', 'T']
# ## In Training the model : categorical column type :  <class 'str'>
# ['F', 'Others', 'missing', 'T']
# ## In Training the model : categorical column type :  <class 'str'>
# ['F', 'Others', 'missing', 'T']
# ## In Training the model : categorical column type :  <class 'str'>
# ['Found', 'missing', 'Others', 'NotFound']
# ## In Training the model : categorical column type :  <class 'str'>
# ['44.0', '15.0', '39.0', '25.0', '56.0', '47.0', '28.0', '18.0', '23.0', '22.0', '60.0', '50.0', '46.0', '17.0', '35.0', 'missing', '14.0', '41.0', '49.0', 'Others', '42.0', '21.0', '51.0', '38.0', '45.0', '12.0', '31.0', '30.0', '11.0', '32.0', '54.0', '29.0', '52.0', '48.0', '26.0', '37.0', '19.0', '20.0', '62.0', '61.0', '33.0', '57.0', '13.0', '27.0', '55.0', '24.0', '53.0', '40.0', '36.0', '64.0', '10.0', '34.0', '58.0', '43.0', '63.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['120.0', '720.0', '270.0', '-300.0', '-360.0', '-480.0', '540.0', '60.0', 'missing', '330.0', 'Others', '0.0', '-600.0', '420.0', '-210.0', '600.0', '180.0', '240.0', '-240.0', '480.0', '-540.0', '-660.0', '-180.0', '-420.0', '300.0', '-120.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['missing', 'Found', 'Others', 'Unknown', 'New']
# ## In Training the model : categorical column type :  <class 'str'>
# ['Found', 'missing', 'Others', 'NotFound']
# ## In Training the model : categorical column type :  <class 'str'>
# ['120.0', '111.0', '205.0', '128.0', '122.0', '119.0', '192.0', '160.0', '126.0', '140.0', '118.0', '146.0', '147.0', '143.0', '198.0', '139.0', '208.0', '190.0', '191.0', '203.0', '116.0', '135.0', '166.0', '148.0', '195.0', '156.0', '211.0', 'Others', '109.0', '154.0', '210.0', '142.0', '164.0', '105.0', '200.0', '153.0', '197.0', '229.0', '127.0', '202.0', '150.0', '217.0', '101.0', '213.0', '226.0', '136.0', '144.0', '182.0', '225.0', '204.0', '201.0', '178.0', '194.0', '114.0', '110.0', '214.0', '175.0', '220.0', '212.0', '177.0', '152.0', '186.0', '134.0', '138.0', '180.0', '157.0', '102.0', '125.0', '171.0', '207.0', '100.0', '124.0', '183.0', '161.0', '185.0', '123.0', '163.0', '219.0', '131.0', '188.0', '133.0', '151.0', 'missing', '141.0', '216.0', '184.0', '199.0', '137.0', '189.0', '155.0', '107.0', '228.0', '158.0', '117.0', '121.0', '159.0', '129.0', '149.0', '106.0', '130.0', '168.0', '145.0', '218.0', '162.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['missing', '15.0', '24.0', '27.0', '29.0', '14.0', '25.0', 'Others', '26.0', '21.0', '20.0', '10.0', '23.0', '18.0', '28.0', '12.0', '13.0', '11.0', '17.0', '16.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['651.0', '597.0', '205.0', '623.0', '567.0', '366.0', '383.0', '511.0', '314.0', '308.0', '517.0', '410.0', '430.0', '245.0', '588.0', '555.0', '208.0', '239.0', '274.0', '304.0', '190.0', '399.0', '559.0', '332.0', '530.0', '262.0', '613.0', '390.0', '643.0', '508.0', '521.0', '434.0', '203.0', '439.0', '318.0', '616.0', '166.0', '487.0', '148.0', '433.0', '526.0', '367.0', '249.0', '356.0', '479.0', '463.0', '537.0', '156.0', '474.0', '582.0', '635.0', '482.0', '187.0', '105.0', '557.0', '614.0', '667.0', '223.0', '419.0', '538.0', '344.0', '617.0', '320.0', '101.0', '250.0', '226.0', '299.0', '485.0', '182.0', '275.0', '415.0', '201.0', '556.0', '327.0', '608.0', '284.0', '639.0', '542.0', '297.0', '394.0', '175.0', '631.0', '345.0', '387.0', '603.0', '578.0', '364.0', '494.0', '138.0', '315.0', '157.0', '246.0', '468.0', '527.0', '171.0', '593.0', '234.0', '473.0', '183.0', '539.0', '424.0', '313.0', '254.0', '268.0', '173.0', '372.0', '328.0', '509.0', '290.0', '224.0', '546.0', '489.0', '296.0', '289.0', '325.0', '375.0', '515.0', '503.0', '492.0', '660.0', '189.0', '305.0', '586.0', '619.0', '121.0', '648.0', '453.0', '301.0', '425.0', '560.0', '359.0', '130.0', '456.0', '145.0', '563.0', '574.0', '655.0', '663.0', '646.0', '215.0', '477.0', '132.0', '532.0', '642.0', '437.0', '122.0', '500.0', '570.0', '242.0', '119.0', '160.0', '259.0', '585.0', '140.0', '118.0', '420.0', '622.0', '146.0', '598.0', '451.0', '664.0', '524.0', '104.0', '621.0', '241.0', '191.0', '610.0', '222.0', '397.0', '401.0', '436.0', '478.0', '300.0', '321.0', '452.0', '353.0', '469.0', '636.0', '103.0', '446.0', '322.0', '195.0', '350.0', '649.0', '307.0', '341.0', '566.0', '432.0', '536.0', '154.0', '233.0', '357.0', '523.0', '202.0', '400.0', '369.0', '150.0', '309.0', '361.0', '611.0', '444.0', '136.0', '398.0', '113.0', '266.0', '564.0', '606.0', '178.0', '362.0', '609.0', '196.0', '282.0', '514.0', '303.0', '491.0', '576.0', '212.0', '112.0', '177.0', '291.0', '152.0', '605.0', '312.0', '650.0', '391.0', '134.0', '411.0', '480.0', '174.0', '316.0', '373.0', '620.0', '665.0', '565.0', '370.0', '335.0', '176.0', '569.0', '219.0', '505.0', '407.0', '151.0', 'missing', '471.0', '277.0', '216.0', '261.0', '633.0', '107.0', '371.0', '669.0', '413.0', '158.0', '416.0', '409.0', '558.0', '638.0', '545.0', '522.0', '129.0', '281.0', '149.0', '583.0', '462.0', '283.0', '389.0', '552.0', '618.0', '490.0', '218.0', '550.0', '294.0', '120.0', '447.0', '167.0', '426.0', '657.0', '330.0', '640.0', '243.0', '310.0', '248.0', '455.0', '441.0', '498.0', '147.0', '551.0', '457.0', '292.0', '340.0', '139.0', '355.0', '427.0', '365.0', '326.0', '378.0', '612.0', '337.0', '382.0', '506.0', '666.0', '403.0', '381.0', '377.0', '108.0', '116.0', '519.0', '435.0', '135.0', '170.0', '428.0', '179.0', '627.0', '319.0', '237.0', '658.0', '333.0', '493.0', '258.0', '654.0', '628.0', '445.0', '339.0', 'Others', '211.0', '109.0', '422.0', '602.0', '589.0', '374.0', '164.0', '440.0', '476.0', '496.0', '625.0', '475.0', '630.0', '306.0', '229.0', '634.0', '127.0', '358.0', '271.0', '396.0', '466.0', '352.0', '581.0', '507.0', '644.0', '225.0', '380.0', '287.0', '472.0', '571.0', '553.0', '256.0', '461.0', '525.0', '194.0', '298.0', '114.0', '214.0', '220.0', '276.0', '615.0', '412.0', '467.0', '251.0', '544.0', '125.0', '668.0', '280.0', '100.0', '161.0', '347.0', '185.0', '541.0', '349.0', '270.0', '163.0', '351.0', '386.0', '385.0', '531.0', '376.0', '199.0', '155.0', '454.0', '607.0', '384.0', '228.0', '348.0', '661.0', '449.0', '168.0', '406.0', '162.0', '601.0', '244.0', '278.0', '360.0', '128.0', '418.0', '431.0', '343.0', '192.0', '311.0', '604.0', '528.0', '641.0', '488.0', '295.0', '272.0', '653.0', '595.0', '572.0', '405.0', '579.0', '671.0', '458.0', '502.0', '632.0', '577.0', '443.0', '535.0', '575.0', '402.0', '442.0', '238.0', '549.0', '481.0', '288.0', '279.0', '252.0', '484.0', '520.0', '263.0', '590.0', '210.0', '142.0', '302.0', '499.0', '153.0', '197.0',  ...
# ## In Training the model : categorical column type :  <class 'str'>
# ['597.0', '623.0', '567.0', '366.0', '383.0', '511.0', '314.0', '308.0', '517.0', '392.0', '410.0', '430.0', '245.0', '588.0', '555.0', '274.0', '239.0', '208.0', '304.0', '190.0', '559.0', '332.0', '530.0', '262.0', '613.0', '390.0', '643.0', '508.0', '521.0', '203.0', '439.0', '318.0', '166.0', '487.0', '433.0', '526.0', '367.0', '540.0', '249.0', '356.0', '463.0', '537.0', '474.0', '635.0', '187.0', '105.0', '614.0', '223.0', '419.0', '538.0', '656.0', '320.0', '101.0', '250.0', '299.0', '485.0', '182.0', '275.0', '415.0', '201.0', '464.0', '336.0', '556.0', '327.0', '639.0', '394.0', '345.0', '387.0', '578.0', '364.0', '494.0', '138.0', '315.0', '255.0', '246.0', '468.0', '527.0', '593.0', '473.0', '539.0', '424.0', '313.0', '254.0', '268.0', '173.0', '372.0', '285.0', '328.0', '509.0', '290.0', '423.0', '489.0', '296.0', '325.0', '660.0', '305.0', '619.0', '121.0', '648.0', '301.0', '560.0', '359.0', '456.0', '145.0', '563.0', '655.0', '273.0', '111.0', '215.0', '477.0', '532.0', '132.0', '437.0', '500.0', '122.0', '570.0', '242.0', '119.0', '160.0', '596.0', '259.0', '354.0', '118.0', '420.0', '146.0', '598.0', '451.0', '143.0', '104.0', '241.0', '191.0', '610.0', '222.0', '401.0', '397.0', '436.0', '478.0', '300.0', '321.0', '452.0', '469.0', '636.0', '181.0', '103.0', '446.0', '322.0', '350.0', '649.0', '566.0', '341.0', '307.0', '432.0', '536.0', '154.0', '357.0', '202.0', '369.0', '400.0', '150.0', '486.0', '611.0', '444.0', '136.0', '113.0', '266.0', '564.0', '178.0', '609.0', '196.0', '282.0', '514.0', '303.0', '491.0', '576.0', '212.0', '112.0', '177.0', '152.0', '312.0', '650.0', '391.0', '411.0', '134.0', '480.0', '316.0', '373.0', '565.0', '370.0', '335.0', '176.0', '569.0', '219.0', '505.0', '407.0', 'missing', '471.0', '277.0', '216.0', '261.0', '633.0', '107.0', '371.0', '638.0', '545.0', '583.0', '462.0', '283.0', '552.0', '490.0', '550.0', '294.0', '120.0', '447.0', '167.0', '426.0', '657.0', '330.0', '640.0', '243.0', '310.0', '248.0', '455.0', '498.0', '551.0', '292.0', '139.0', '340.0', '355.0', '427.0', '378.0', '612.0', '337.0', '506.0', '381.0', '377.0', '108.0', '116.0', '519.0', '435.0', '170.0', '428.0', '333.0', '258.0', '628.0', '445.0', '339.0', 'Others', '211.0', '109.0', '602.0', '374.0', '440.0', '476.0', '496.0', '306.0', '630.0', '127.0', '634.0', '358.0', '271.0', '396.0', '466.0', '352.0', '581.0', '448.0', '507.0', '644.0', '225.0', '380.0', '472.0', '629.0', '553.0', '256.0', '525.0', '194.0', '298.0', '214.0', '220.0', '615.0', '251.0', '280.0', '100.0', '161.0', '347.0', '185.0', '541.0', '349.0', '270.0', '351.0', '385.0', '531.0', '376.0', '199.0', '155.0', '607.0', '384.0', '228.0', '348.0', '661.0', '449.0', '168.0', '244.0', '278.0', '360.0', '431.0', '343.0', '192.0', '311.0', '604.0', '641.0', '272.0', '595.0', '572.0', '458.0', '502.0', '632.0', '443.0', '535.0', '575.0', '442.0', '549.0', '481.0', '288.0', '279.0', '252.0', '484.0', '590.0', '142.0', '408.0', '499.0', '153.0', '497.0', '197.0', '562.0', '645.0', '568.0', '265.0', '213.0', '561.0', '543.0', '144.0', '232.0', '317.0', '204.0', '483.0', '393.0', '269.0', '652.0', '323.0', '110.0', '253.0', '388.0', '186.0', '180.0', '368.0', '533.0', '379.0', '659.0', '235.0', '554.0', '102.0', '209.0', '124.0', '547.0', '123.0', '459.0', '165.0', '286.0', '131.0', '188.0', '133.0', '587.0', '324.0', '414.0', '184.0', '417.0', '460.0', '600.0', '117.0', '236.0', '193.0', '501.0', '342.0', '240.0', '429.0', '346.0', '404.0', '221.0', '247.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['813.0', '597.0', '834.0', '793.0', '770.0', '511.0', '517.0', '308.0', '773.0', '392.0', '470.0', '410.0', '245.0', '588.0', '208.0', '239.0', '190.0', '559.0', '703.0', '332.0', '530.0', '262.0', '613.0', '390.0', '643.0', '434.0', '521.0', '439.0', '318.0', '166.0', '487.0', '433.0', '367.0', '249.0', '540.0', '479.0', '783.0', '463.0', '537.0', '156.0', '582.0', '187.0', '105.0', '667.0', '223.0', '538.0', '771.0', '101.0', '250.0', '226.0', '299.0', '485.0', '794.0', '182.0', '275.0', '415.0', '201.0', '336.0', '786.0', '556.0', '790.0', '327.0', '608.0', '639.0', '542.0', '297.0', '394.0', '345.0', '728.0', '387.0', '578.0', '724.0', '727.0', '255.0', '157.0', '246.0', '764.0', '593.0', '234.0', '183.0', '424.0', '268.0', '254.0', '713.0', '720.0', '173.0', '372.0', '804.0', '509.0', '290.0', '224.0', '825.0', '798.0', '289.0', '515.0', '375.0', '325.0', '503.0', '189.0', '660.0', '305.0', '722.0', '586.0', '796.0', '121.0', '453.0', '648.0', '301.0', '560.0', '748.0', '456.0', '130.0', '145.0', '563.0', '846.0', '655.0', '831.0', '646.0', '215.0', '751.0', '532.0', '132.0', '477.0', '437.0', '500.0', '570.0', '329.0', '840.0', '119.0', '835.0', '160.0', '596.0', '599.0', '126.0', '699.0', '420.0', '680.0', '622.0', '761.0', '146.0', '598.0', '664.0', '734.0', '451.0', '524.0', '812.0', '851.0', '621.0', '241.0', '814.0', '610.0', '222.0', '401.0', '436.0', '397.0', '478.0', '353.0', '452.0', '817.0', '469.0', '334.0', '697.0', '446.0', '322.0', '195.0', '350.0', '649.0', '566.0', '307.0', '432.0', '536.0', '154.0', '741.0', '695.0', '523.0', '369.0', '781.0', '309.0', '169.0', '361.0', '675.0', '444.0', '398.0', '113.0', '266.0', '606.0', '564.0', '178.0', '362.0', '609.0', '682.0', '196.0', '839.0', '282.0', '514.0', '805.0', '303.0', '491.0', '576.0', '212.0', '177.0', '312.0', '391.0', '134.0', '480.0', '373.0', '665.0', '335.0', '569.0', '505.0', '407.0', '151.0', 'missing', '471.0', '277.0', '216.0', '803.0', '692.0', '776.0', '371.0', '669.0', '413.0', '158.0', '409.0', '638.0', '281.0', '149.0', '583.0', '462.0', '283.0', '787.0', '688.0', '618.0', '218.0', '550.0', '293.0', '694.0', '447.0', '725.0', '167.0', '657.0', '330.0', '640.0', '243.0', '248.0', '441.0', '498.0', '637.0', '147.0', '457.0', '683.0', '427.0', '355.0', '378.0', '612.0', '337.0', '506.0', '666.0', '403.0', '381.0', '377.0', '519.0', '816.0', '135.0', '170.0', '435.0', '428.0', '854.0', '237.0', '658.0', '333.0', '753.0', '493.0', '258.0', '654.0', '445.0', '339.0', 'Others', '853.0', '109.0', '700.0', '602.0', '589.0', '829.0', '845.0', '440.0', '164.0', '625.0', '264.0', '475.0', '306.0', '630.0', '229.0', '634.0', '819.0', '809.0', '838.0', '358.0', '396.0', '352.0', '848.0', '448.0', '507.0', '581.0', '644.0', '225.0', '287.0', '472.0', '677.0', '795.0', '571.0', '256.0', '525.0', '298.0', '114.0', '743.0', '214.0', '716.0', '766.0', '276.0', '800.0', '762.0', '827.0', '251.0', '844.0', '544.0', '668.0', '100.0', '347.0', '230.0', '185.0', '541.0', '349.0', '738.0', '754.0', '351.0', '760.0', '531.0', '849.0', '801.0', '607.0', '228.0', '797.0', '661.0', '449.0', '406.0', '162.0', '601.0', '244.0', '360.0', '418.0', '431.0', '709.0', '192.0', '750.0', '604.0', '528.0', '806.0', '641.0', '488.0', '624.0', '767.0', '684.0', '595.0', '572.0', '405.0', '671.0', '458.0', '810.0', '443.0', '632.0', '577.0', '575.0', '535.0', '755.0', '402.0', '807.0', '549.0', '481.0', '288.0', '279.0', '252.0', '484.0', '763.0', '263.0', '689.0', '799.0', '590.0', '142.0', '744.0', '408.0', '499.0', '497.0', '197.0', '645.0', '719.0', '267.0', '822.0', '792.0', '115.0', '510.0', '213.0', '561.0', '144.0', '232.0', '204.0', '269.0', '802.0', '323.0', '260.0', '253.0', '820.0', '681.0', '686.0', '388.0', '726.0', '186.0', '368.0', '533.0', '379.0', '659.0', '758.0', '235.0', '554.0', '102.0', '691.0', '512.0', '818.0', '548.0', '547.0', '788.0', '338.0', '257.0', '459.0', '123.0', '673.0', '286.0', '131.0', '133.0', '731.0', '587.0', '715.0', '324.0', '647.0',  ...
# ## In Training the model : categorical column type :  <class 'str'>
# ['44.0', '39.0', '23.0', '28.0', '18.0', '22.0', '17.0', '35.0', 'missing', '14.0', '41.0', 'Others', '42.0', '21.0', '38.0', '12.0', '31.0', '26.0', '37.0', '20.0', '19.0', '33.0', '24.0', '40.0', '36.0', '10.0', '43.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['missing', 'IP_PROXY:ANONYMOUS', 'IP_PROXY:HIDDEN', 'Others', 'IP_PROXY:TRANSPARENT']
# ## In Training the model : categorical column type :  <class 'str'>
# ['missing', '15.0', '24.0', '25.0', 'Others', '26.0', '21.0', '19.0', '18.0', '12.0', '11.0', '17.0', '16.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['273.0', '294.0', '120.0', '111.0', '205.0', '132.0', '458.0', '278.0', '360.0', '128.0', '418.0', '167.0', '437.0', '426.0', '431.0', '544.0', '122.0', '366.0', '329.0', '500.0', '242.0', '511.0', '343.0', '119.0', '160.0', '450.0', '311.0', '308.0', '517.0', '330.0', '126.0', '528.0', '259.0', '354.0', '243.0', '310.0', '470.0', '118.0', '410.0', '392.0', '455.0', '248.0', '146.0', '498.0', '430.0', '527.0', '488.0', '451.0', '457.0', '245.0', '524.0', '292.0', '143.0', '104.0', '198.0', '139.0', '355.0', '427.0', '208.0', '239.0', '274.0', '365.0', '304.0', '272.0', '331.0', '326.0', '190.0', '241.0', '378.0', '332.0', '337.0', '191.0', '530.0', '382.0', '262.0', '506.0', '436.0', '405.0', '508.0', '206.0', '381.0', '521.0', '321.0', '203.0', '439.0', '108.0', '443.0', '377.0', '519.0', '452.0', '535.0', '116.0', '170.0', '435.0', '166.0', '148.0', '353.0', '433.0', '469.0', '334.0', '402.0', '442.0', '238.0', '237.0', '367.0', '319.0', '333.0', '181.0', '481.0', '493.0', '258.0', '356.0', '479.0', '103.0', '445.0', '463.0', '339.0', '446.0', '252.0', '195.0', 'Others', '484.0', '211.0', '350.0', '474.0', '520.0', '307.0', '263.0', '341.0', '233.0', '154.0', '422.0', '210.0', '142.0', '440.0', '187.0', '302.0', '374.0', '496.0', '164.0', '357.0', '499.0', '475.0', '200.0', '523.0', '306.0', '497.0', '197.0', '495.0', '223.0', '202.0', '538.0', '369.0', '400.0', '309.0', '358.0', '271.0', '396.0', '344.0', '486.0', '267.0', '217.0', '352.0', '101.0', '510.0', '213.0', '444.0', '543.0', '226.0', '421.0', '299.0', '485.0', '144.0', '136.0', '225.0', '275.0', '232.0', '250.0', '204.0', '182.0', '287.0', '472.0', '113.0', '529.0', '483.0', '269.0', '266.0', '201.0', '336.0', '518.0', '525.0', '178.0', '231.0', '194.0', '327.0', '461.0', '284.0', '196.0', '298.0', '114.0', '514.0', '297.0', '110.0', '175.0', '214.0', '345.0', '212.0', '253.0', '387.0', '276.0', '177.0', '291.0', '112.0', '152.0', '412.0', '388.0', '312.0', '172.0', '467.0', '186.0', '391.0', '364.0', '134.0', '180.0', '368.0', '533.0', '251.0', '157.0', '255.0', '246.0', '379.0', '102.0', '174.0', '468.0', '480.0', '171.0', '125.0', '207.0', '512.0', '234.0', '235.0', '100.0', '548.0', '373.0', '438.0', '209.0', '124.0', '183.0', '539.0', '424.0', '161.0', '347.0', '313.0', '268.0', '254.0', '541.0', '185.0', '349.0', '338.0', '173.0', '270.0', '123.0', '459.0', '163.0', '370.0', '372.0', '165.0', '351.0', '403.0', '286.0', '131.0', '505.0', '188.0', '407.0', '509.0', '385.0', '290.0', '133.0', '151.0', 'missing', '224.0', '531.0', '471.0', '324.0', '414.0', '141.0', '277.0', '489.0', '296.0', '289.0', '216.0', '184.0', '325.0', '375.0', '515.0', '503.0', '492.0', '376.0', '261.0', '137.0', '155.0', '305.0', '460.0', '371.0', '417.0', '189.0', '454.0', '384.0', '228.0', '348.0', '158.0', '416.0', '236.0', '409.0', '193.0', '501.0', '453.0', '301.0', '342.0', '545.0', '425.0', '240.0', '281.0', '449.0', '106.0', '359.0', '346.0', '130.0', '145.0', '404.0', '406.0', '516.0', '490.0', '504.0', '221.0', '247.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['120.0', '111.0', '215.0', '205.0', '128.0', '167.0', '122.0', '119.0', '192.0', '160.0', '126.0', '118.0', '146.0', '147.0', '143.0', '198.0', '208.0', '190.0', '191.0', '206.0', '203.0', '108.0', '116.0', '170.0', '103.0', '156.0', '195.0', '211.0', 'Others', '109.0', '142.0', '164.0', '187.0', '200.0', '153.0', '127.0', '202.0', '150.0', '169.0', '115.0', '101.0', '136.0', '144.0', '182.0', '204.0', '113.0', '201.0', '178.0', '194.0', '114.0', '110.0', '214.0', '212.0', '177.0', '152.0', '172.0', '186.0', '134.0', '138.0', '180.0', '157.0', '102.0', '174.0', '125.0', '209.0', '100.0', '124.0', '183.0', '161.0', '185.0', '123.0', '163.0', '165.0', '176.0', '133.0', 'missing', '141.0', '184.0', '216.0', '199.0', '137.0', '189.0', '155.0', '107.0', '158.0', '117.0', '121.0', '193.0', '159.0', '129.0', '149.0', '106.0', '168.0', '130.0', '145.0', '162.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['Found', 'missing', 'Others', 'NotFound']
# ## In Training the model : categorical column type :  <class 'str'>
# ['New', 'Found', 'missing', 'Others']
# ## In Training the model : categorical column type :  <class 'str'>
# ['Found', 'missing', 'Others', 'NotFound']
# ## In Training the model : categorical column type :  <class 'str'>
# ['iOS', 'missing', 'Linux', 'Android', 'other', 'Others', 'func', 'Mac', 'Windows']
# ## In Training the model : categorical column type :  <class 'str'>
# ['Generic/Android', 'aol', 'iron', 'Generic/Android 7.0', 'palemoon', 'M4Tel/M4', 'missing', 'waterfox', 'line', 'Cherry', 'Others', 'puffin', 'chromium', 'google search application 49.0', 'Nokia/Lumia', 'maxthon', 'Edge', 'Firefox', 'cyberfox', 'mobile', 'other', 'Samsung', 'Samsung/SM-G532M', 'icedragon', 'Opera', 'IE', 'Chrome', 'Samsung/SM-G531H', 'Inco/Minion', 'seamonkey', 'android browser 4.0', 'Safari', 'comodo', 'google search application 48.0', 'facebook', 'Mozilla/Firefox', 'Microsoft/Windows', 'BLU/Dash', 'silk', 'ZTE/Blade', 'Lanix/Ilium', 'android', 'google']
# ## In Training the model : categorical column type :  <class 'str'>
# ['32.0', 'missing', '24.0', 'Others', '0.0', '16.0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['1360x768', '1365x767', '1600x900', '1680x1049', '2880x1620', '1440x899', '1536x960', '640x360', '3360x1050', '6016x3384', '1805x1015', '2736x1823', '1440x803', '1600x1200', '2732x2048', '3360x1890', '3838x2160', '2562x1442', '1888x941', '1921x1081', '1344x756', '2076x1080', '1152x864', '1920x1201', '4096x2304', '1264x924', '2560x1600', '3201x1800', '2160x1080', '2561x1442', '2256x1504', '2552x1337', '2304x1296', '1600x899', '1400x900', '1599x900', '1919x1199', '1920x1200', '1920x1079', '1824x1026', '1776x1080', '2049x1152', '2880x1442', '2882x1442', '2559x1440', '1279x1024', '1920x975', '1400x1050', '1658x946', '2100x1312', '5120x2880', '5760x3240', '1188x720', '1062x630', '2368x1440', '3240x2160', '1912x1025', '1768x992', '3838x2158', '1920x1080', '1368x768', '1296x774', '1680x1050', '600x450', '2048x1080', '2560x1800', '1280x900', '2960x1440', '1280x768', '1371x857', '2735x1823', '2816x1584', '3841x2161', '2048x1280', '4200x2625', '2160x1350', '2208x1242', '1280x732', '1920x1018', '1280x620', 'Others', '1023x767', '1760x990', '4500x3000', '2560x1700', '2048x1536', '480x320', '3840x1600', '1439x899', '3839x2160', '1281x720', '1624x1080', '3840x2400', '2560x1080', '2048x1152', '1281x800', '1600x837', '1239x697', '2672x1440', '2224x1668', '1025x768', '2800x1575', '1422x889', '2880x1440', '2880x1800', '3000x2000', '3200x1800', '1480x720', '1356x900', '1440x900', '1439x900', '1366x1024', '1919x1200', '1729x973', '1120x700', '1440x960', '1138x640', '3600x2250', '1496x844', '1280x712', '1184x720', '2560x1440', '2400x1600', '1638x922', '1200x720', '960x640', '2736x1824', '2710x1440', '2737x1825', '2436x1125', '1920x1281', '3840x1080', '1360x767', '1800x1125', '1600x1024', '1280x960', '1366x767', '1024x819', '3360x2100', '1280x1025', '6720x3780', '801x480', '3072x1728', '3199x1800', '2048x1278', '2559x1439', '2961x1440', '2400x1500', '1200x675', '1280x720', '855x480', '1502x845', '3200x2000', '2400x1350', '1599x899', '1919x1080', '2961x1442', '1707x960', '1359x768', '1232x800', '2160x1439', '2160x1081', '1136x640', '1439x809', '5760x1080', '2220x1081', '2392x1440', '1679x1049', '1920x1081', '1364x768', '5040x3150', '2112x1188', '1440x810', '1408x880', '1680x1051', '800x600', '1440x800', '1152x720', '1921x1080', '1152x648', '1093x615', '1365x768', '1920x1279', '2999x2000', '2816x1760', '960x540', '1023x768', '7500x5000', '1024x767', '2220x1080', '1919x1079', '1280x1023', '4499x2999', '1920x1280', '2159x1439', 'missing', '3840x2160', '1536x864', '1024x600', '2000x1125', '2255x1503', '2049x1536', '3441x1440', '3440x1440', '1727x971', '1279x1023', '1440x720', '3001x2000', '1600x1000', '3696x2310', '1344x840', '1536x1152', '2735x1825', '1502x844', '1281x801', '1024x552', '1280x600', '1584x990', '1684x947', '1916x901', '1680x945', '1728x972', '2159x1440', '1334x750', '1024x640', '1281x721', '3840x2162', '2001x1125', '1596x710', '1440x759', '921x691', '768x576', '1848x1155', '2520x1575', '1272x960', '2304x1440', '1441x901', '2160x1440', '1408x792', '1024x768', '2160x1215', '2700x1800', '1280x1024', '1366x768', '1229x691', '1776x1000', '3520x1980', '1280x800', '0x0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['missing', 'match_status:1', 'Others', 'match_status:-1', 'match_status:2', 'match_status:0']
# ## In Training the model : categorical column type :  <class 'str'>
# ['F', 'Others', 'missing', 'T']
# ## In Training the model : categorical column type :  <class 'str'>
# ['F', 'Others', 'missing', 'T']
# ## In Training the model : categorical column type :  <class 'str'>
# ['F', 'Others', 'missing', 'T']
# ## In Training the model : categorical column type :  <class 'str'>
# ['F', 'Others', 'missing', 'T']
# ## In Training the model : categorical column type :  <class 'str'>
# ['desktop', 'mobile', 'missing', 'Others']
# ## In Training the model : categorical column type :  <class 'str'>
# ['SCH-I435', 'XT1575 Build/NPHS25.200-23-1', 'Alumini3 Build/MRA58K', 'SM-N920V', 'SM-G900T Build/MMB29M', 'LG-H820', 'ZA409', 'COVET Build/NRD90M', 'rv:54.0', 'Hisense F20 Build/MMB29M', 'GRACE', 'SM-G900P Build/MMB29M', 'Moto C Build/NRD90M.050', 'SM-J700F', 'XT1092', 'Max', 'SM-G928V', 'BG2-W09', 'Lenovo A2016b30 Build/MRA58K', 'SM-J327T Build/NRD90M', 'D5316 Build/19.4.A.0.182', 'Aquaris X5 Plus Build/NMF26F', 'SM-J700T Build/NMF26X', 'SM-S920L', 'SM-T377V Build/NMF26X', 'Lenovo PB2-670Y Build/MRA58K', 'Moto', 'SM-G892A', 'H550', 'LG-H631', 'XT1572 Build/NPHS25.200-15-8', 'KFTHWI Build/KTU84M', 'Azumi_KINZO_A5_QL', 'SM-N920G Build/NRD90M', 'XT1032 Build/LPBS23.13-57-2', 'Z963VL', 'Lenovo TAB 2 A7-30GC Build/KOT49H', '5054S Build/LMY47V', 'F3213 Build/36.0.A.2.146', 'SM-J500H', 'HTCD200LVW', 'PULP 4G Build/LMY47V', 'SM-G550T Build/MMB29K', 'RS988', 'HUAWEI LUA-U23 Build/HUAWEILUA-U23', 'D6603', 'SAMSUNG SM-G965F Build/R16NW', 'Pixel 2 XL Build/OPM1.171019.011', 'C6743 Build/LMY47V', 'E6653 Build/32.4.A.1.54', 'Blade V6 Max Build/MRA58K', 'SM-P580 Build/NRD90M', 'HTC6500LVW', 'SM-G360F', 'SAMSUNG-SM-G925A Build/NRD90M', 'rv:43.0', 'rv:29.0', 'Moto G Play Build/NPI26.48-36', 'SAMSUNG-SM-G935A Build/NRD90M', '1016S', 'Mi', 'SM-G935T Build/NRD90M', 'A466BG', 'E6853', 'SAMSUNG SM-J700M Build/LMY48B', 'GT-I9515', 'ALE-L21 Build/HuaweiALE-L21', 'H1711 Build/HUAWEIH1711', 'SAMSUNG-SM-G900A Build/LMY47X', 'LGMS330 Build/LMY47V', 'SM-J710MN Build/MMB29K', 'Moto G (5) Plus Build/NPNS25.137-93-8', 'SM-T380', 'F5321 Build/34.2.A.2.47', 'SLA-L02', 'verykoolS5525', 'SM-G7105', 'CRO-L03 Build/HUAWEICRO-L03', 'XT1635-02 Build/OPN27.76-12-22', 'ALTER', 'LGL164VL Build/NRD90U', 'gxq6580_weg_l Build/LMY47I', 'Edison', 'VS990 Build/MRA58K', 'XT1650', 'VS500', 'SGH-M919 Build/KTU84P', 'GT-N5110 Build/JDQ39', 'SM-T320 Build/KOT49H', 'SM-J320V Build/MMB29M', 'E6553', 'Android 7.1.2', 'rv:52.0', 'HUAWEI VNS-L23 Build/HUAWEIVNS-L23', 'XT1565', 'Windows', 'SM-P355M', '5044A', 'SM-T280 Build/LMY47V', 'SM-J500FN', 'Redmi 3S Build/MMB29M', 'F80 PIABELLA Build/MRA58K', '0PJA2', 'HUAWEI VNS-L31 Build/HUAWEIVNS-L31', 'SM-J700T Build/MMB29K', 'VS980 4G Build/LRX22G', 'Lenovo TB-7703X Build/S100', 'M4', 'SM-T113 Build/KTU84P', 'SM-G903M', 'KFSUWI Build/LVY48F', 'MYA-L03 Build/HUAWEIMYA-L03', 'VS996 Build/OPR1.170623.026', 'LG-SP320', 'SM-T817V Build/NRD90M', 'SM-A300FU Build/MMB29M', 'SM-A300M Build/KTU84P', 'WAS-LX1 Build/HUAWEIWAS-LX1', 'DT0704K08', 'Wileyfox', 'BBA100-1', 'E2104', '6037B', 'Beat', '5056A Build/MMB29M', 'Z833', 'XT1635-01 Build/NDNS26.118-23-12-3', 'Tmovi Build/Vision', 'Moto G (4) Build/NPJ25.93-14', 'VFD', 'SAMSUNG SM-A310M Build/LMY47X', 'Moto C Build/NRD90M.057', 'SAMSUNG SM-J700T1 Build/NMF26X', 'SM-T537V', 'SAMSUNG SM-G610M Build/MMB29K', 'SM-N950U Build/NMF26X', 'SM-N900T Build/LRX21V', 'SM-J510F', 'LGLS755', 'SM-N910P', 'LG-D851', '2PS64 Build/NRD90M', 'X78', 'Build/OPM1.171019.011', 'SGH-I317M', 'SAMSUNG SM-N910A Build/MMB29M', 'SM-T285M', 'TA-1028 Build/NRD90M', 'SM-G920T1', 'SM-G920I', 'Ilium X520 Build/NRD90M', 'SAMSUNG SM-J510MN Build/MMB29M', 'MotoG3 Build/MPI24.65-25.1', 'Android 5.1', 'SM-P607T', 'LG-H345', 'SM-A800I', 'XT1063 Build/MPB24.65-34', 'VS988 Build/NRD90U', 'SAMSUNG-SM-G870A Build/MMB29M', 'SM-J727V Build/NRD90M', 'T08', 'SM-T810 Build/NRD90M', 'G8341', 'moto x4 Build/NPW26.83-18-2-0-4', 'VS986 Build/MRA58K', 'XT1003', 'ASUS_X00DD', 'BLL-L23 Build/HUAWEIBLL-L23', 'F5321 Build/34.3.A.0.238', 'SAMSUNG-SM-G928A Build/NRD90M', 'SM-G935P Build/NRD90M', 'LG-TP260 Build/NRD90U', 'Moto E (4) Build/NCQ26.69-56', 'GT-S7580L Build/JDQ39', '8050G Build/LMY47I', 'Aquaris X Build/NMF26F', 'GT-S7582', 'verykools4009', 'SAMSUNG SM-A320FL Build/NRD90M', 'SM-G532M Build/MMB29T', 'rv:41.0', 'P5026A', 'Dream', 'SAMSUNG-SM-J727AZ', 'Blade L3 Build/KOT49H', 'SM-G925T Build/LMY47X', 'TA-1028 Build/O00623', 'KFASWI Build/LVY48F', 'E6790TM', 'LG-M327 Build/NRD90U', 'XT1563 Build/MPD24.107-52', 'SM-J320W8', 'LG-H931', 'LenovoA3300-GV Buil ...
# ## Preprocessing - Scaling numerical features
# ## Training - training the model
# Saving the model
#
# *************************Predicting for Train data*************************
# ## Data Cleaning - filling missing values for categorical data
# ## Data Cleaning - filling missing values for numerical data
# ## Data Preprocessing - loading labelencoder
# ## Data Preprocessing - loading minmaxscalar
# ## Predicting - Load model
# ## Predicting - predicting values
#
# *************************Predicting for CV data*************************
# ## Data Cleaning - filling missing values for categorical data
# ## Data Cleaning - filling missing values for numerical data
# ## Data Preprocessing - loading labelencoder
# ## Data Preprocessing - loading minmaxscalar
# ## Predicting - Load model
# ## Predicting - predicting values
#
#
# Train metric :  0.9352578669442296
# CV metric :  0.9179854808515588

# %%
# Predict Test values.
print('\n' + '*'*25 + 'Predicting for Test data' + '*'*25)
test_predict = final_model(test_df.copy(deep=True))

# update sample submission file
sample_df = pd.read_csv(data_path_ + 'sample_submission.csv')
sample_df['isFraud'] = test_predict
print('Sample test predictions')
sample_df.to_csv(data_path_ + 'sample_submission.csv', index=False)

# Display Sample test results
display(sample_df.head(50))
# Out:
# *************************Predicting for Test data*************************
# ## Data Cleaning - filling missing values for categorical data
# ## Data Cleaning - filling missing values for numerical data
# ## Data Preprocessing - loading labelencoder
# ## Data Preprocessing - loading minmaxscalar
# ## Predicting - Load model
# ## Predicting - predicting values
# Sample test predictions
#     TransactionID   isFraud
# 0         3663549  0.004229
# 1         3663550  0.007167
# 2         3663551  0.014773
# 3         3663552  0.003354
# 4         3663553  0.004792
# 5         3663554  0.005201
# 6         3663555  0.029364
# 7         3663556  0.031288
# 8         3663557  0.001784
# 9         3663558  0.011448
# 10        3663559  0.007672
# 11        3663560  0.004908
# 12        3663561  0.022097
# 13        3663562  0.011914
# 14        3663563  0.006350
# 15        3663564  0.005568
# 16        3663565  0.011133
# 17        3663566  0.005363
# 18        3663567  0.027061
# 19        3663568  0.013626
# 20        3663569  0.014230
# 21        3663570  0.006223
# 22        3663571  0.017470
# 23        3663572  0.008125
# 24        3663573  0.030836
# 25        3663574  0.018441
# 26        3663575  0.016298
# 27        3663576  0.026735
# 28        3663577  0.008949
# 29        3663578  0.007033
# 30        3663579  0.067275
# 31        3663580  0.009701
# 32        3663581  0.059323
# 33        3663582  0.016088
# 34        3663583  0.003039
# 35        3663584  0.008978
# 36        3663585  0.017431
# 37        3663586  0.086010
# 38        3663587  0.072201
# 39        3663588  0.072545
# 40        3663589  0.106685
# 41        3663590  0.004579
# 42        3663591  0.004553
# 43        3663592  0.014646
# 44        3663593  0.008129
# 45        3663594  0.045230
# 46        3663595  0.003125
# 47        3663596  0.003421
# 48        3663597  0.007369
# 49        3663598  0.059897

# %%
print('*'*50 + 'The End' + '*'*50)
# Out:
# **************************************************The End**************************************************
